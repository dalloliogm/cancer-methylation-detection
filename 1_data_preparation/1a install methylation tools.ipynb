# %% [markdown]
# # Methylation tools
#
# This notebook originally installed several tools for calling Methylation beta values from the raw files.
#
# However, it turns out that this is not necessary, as the files used in the Nanopore dataset of interest have already been processed.

# %%
# %sh

pip install -q megalodon

# %%
# !megalodon

# %%
# %sh
# git clone https://github.com/epi2me-labs/modbamtools.git
# cd modbamtools
# pip install .

# %% [markdown]
# ## Install modkit (tool for aligning reads)
#
# See https://github.com/nanoporetech/modkit/?tab=readme-ov-file

# %%
# Step 1: Install Rust (via rustup)
# !curl https://sh.rustup.rs -sSf | sh -s -- -y
# !source $HOME/.cargo/env

# Step 2: Clone and build modkit
# !git clone https://github.com/nanoporetech/modkit.git
# %cd modkit
!~/.cargo/bin/cargo install --path .

# Step 3: Add modkit to PATH
import os
os.environ['PATH'] = f"{os.environ['HOME']}/.cargo/bin:" + os.environ['PATH']
