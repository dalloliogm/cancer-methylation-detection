# %%
# !pip install -q mamba
dbutils.library.restartPython()

# %%
# !du -sh ../*

# %%
# !mamba create -n modbam2bed modbam2bed -c bioconda -c conda-forge -c epi2melabs

# %%
https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE185307&format=file
